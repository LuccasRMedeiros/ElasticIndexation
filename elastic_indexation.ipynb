# %%
from elasticsearch import Elasticsearch
import json
import pandas as pd

# %%
ds = pd.ExcelFile("xls_conformidade_site_2020_10_v1.xls")
df = ds.parse(sheet_name=0,skiprows=41)
df = df.drop(['CÓDIGO GGREM', 'REGISTRO', 'EAN 1', 'EAN 2', 'EAN 3','CAP','CONFAZ 87', 'ANÁLISE RECURSAL'], axis=1)
totalrow = df.shape[0]

# %%
print("Changing columns names")
df.columns = [
    "substance",
    "cnpj",
    "lab",
    "product",
    "presentation",
    "class",
    "type",
    "price_regim",
    "fabricprice_no_tax",
    "fabricprice_less_than_1%_tax",
    "fabricprice_12%_tax",
    "fabricprice_17%_tax",
    "fabricprice_17%ALC_tax",
    "fabricprice_17.5%_tax",
    "fabricprice_17.5%ALC_tax",
    "fabricprice_18%_tax",
    "fabricprice_18%ALC_tax",
    "fabricprice_20%_tax",
    "marketprice_less_than_1%_tax",
    "marketprice_12%_tax",
    "marketprice_17%_tax",
    "marketprice_17%ALC_tax",
    "marketprice_17.5%_tax",
    "marketprice_17.5%ALC_tax",
    "marketprice_18%_tax",
    "marketprice_18%ALC_tax",
    "marketprice_20%_tax",
    "restriction",
    "icms_no_tax",
    "tribute_credit",
    "comercialization_last_year",
    "label"
]
print("Names were changed")
# Out:
# Changing columns names
# Names were changed

# %%
print("Formating cells data for properly fit in the document")
for col in range(8, 27):
    for row in df.axes[0]:
        if type(df.iloc[row, col]) == str:
            df.iloc[row, col] = df.iloc[row, col].replace(',', '.')
            df.iloc[row, col] = float(df.iloc[row, col])
            print(f'Row: {row}', end='\r')
    
    df.iloc[:,:col+1] = df.iloc[:,:col+1].fillna(0)
    print(f'Completed {col - 7} of {27 - 8} columns')

print("Concluded")
# Out:
# Formating cells data for properly fit in the document
# Completed 1 of 19 columns
# Completed 2 of 19 columns
# Completed 3 of 19 columns
# Completed 4 of 19 columns
# Completed 5 of 19 columns
# Completed 6 of 19 columns
# Completed 7 of 19 columns
# Completed 8 of 19 columns
# Completed 9 of 19 columns
# Completed 10 of 19 columns
# Completed 11 of 19 columns
# Completed 12 of 19 columns
# Completed 13 of 19 columns
# Completed 14 of 19 columns
# Completed 15 of 19 columns
# Completed 16 of 19 columns
# Completed 17 of 19 columns
# Completed 18 of 19 columns
# Completed 19 of 19 columns
# Concluded

# %%
df.head(30)
# Out:
#                                  substance                cnpj  \
# 0   21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 1                               ABATACEPTE  56.998.982/0001-07
# 2                               ABATACEPTE  56.998.982/0001-07
# 3                               ABATACEPTE  56.998.982/0001-07
# 4                               ABCIXIMABE  51.780.468/0001-87
# 5                               ABCIXIMABE  43.940.618/0001-44
# 6                             ABEMACICLIBE  43.940.618/0001-44
# 7                             ABEMACICLIBE  43.940.618/0001-44
# 8                             ABEMACICLIBE  43.940.618/0001-44
# 9                             ABEMACICLIBE  43.940.618/0001-44
# 10                            ABEMACICLIBE  43.940.618/0001-44
# 11                            ABEMACICLIBE  43.940.618/0001-44
# 12                            ABEMACICLIBE  43.940.618/0001-44
# 13                            ABEMACICLIBE  43.940.618/0001-44
# 14                          ACALABRUTINIBE  60.318.797/0001-00
# 15                                ACARBOSE  18.459.628/0001-15
# 16                                ACARBOSE  18.459.628/0001-15
# 17                                ACARBOSE  00.923.140/0001-31
# 18                                ACARBOSE  00.923.140/0001-31
# 19                                ACARBOSE  00.923.140/0001-31
# 20                                ACARBOSE  00.923.140/0001-31
# 21                            ACEBROFILINA  57.507.378/0003-65
# 22                            ACEBROFILINA  57.507.378/0003-65
# 23                            ACEBROFILINA  83.874.628/0001-43
# 24                            ACEBROFILINA  61.190.096/0001-92
# 25                            ACEBROFILINA  60.665.981/0001-18
# 26                            ACEBROFILINA  02.814.497/0001-07
# 27                            ACEBROFILINA  02.814.497/0001-07
# 28                            ACEBROFILINA  17.159.229/0001-76
# 29                            ACEBROFILINA  83.874.628/0001-43
#
#                                         lab       product  \
# 0                                BAYER S.A.    BAYCUTEN N
# 1    BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA       ORENCIA
# 2    BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA       ORENCIA
# 3    BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA       ORENCIA
# 4           JANSSEN-CILAG FARMACÊUTICA LTDA        REOPRO
# 5                  ELI LILLY DO BRASIL LTDA        REOPRO
# 6                  ELI LILLY DO BRASIL LTDA     VERZENIOS
# 7                  ELI LILLY DO BRASIL LTDA     VERZENIOS
# 8                  ELI LILLY DO BRASIL LTDA     VERZENIOS
# 9                  ELI LILLY DO BRASIL LTDA     VERZENIOS
# 10                 ELI LILLY DO BRASIL LTDA     VERZENIOS
# 11                 ELI LILLY DO BRASIL LTDA     VERZENIOS
# 12                 ELI LILLY DO BRASIL LTDA     VERZENIOS
# 13                 ELI LILLY DO BRASIL LTDA     VERZENIOS
# 14               ASTRAZENECA DO BRASIL LTDA     CALQUENCE
# 15                               BAYER S.A.      GLUCOBAY
# 16                               BAYER S.A.      GLUCOBAY
# 17                    EMS SIGMA PHARMA LTDA      AGLUCOSE
# 18                    EMS SIGMA PHARMA LTDA      AGLUCOSE
# 19                    EMS SIGMA PHARMA LTDA      AGLUCOSE
# 20                    EMS SIGMA PHARMA LTDA      AGLUCOSE
# 21                                  EMS S/A  ACEBROFILINA
# 22                                  EMS S/A  ACEBROFILINA
# 23     LABORATÓRIO FARMACÊUTICO ELOFAR LTDA       LISOMUC
# 24              EUROFARMA LABORATÓRIOS S.A.     FILINAR G
# 25  UNIÃO QUÍMICA FARMACÊUTICA NACIONAL S/A  ACEBROFILINA
# 26     CIMED INDÚSTRIA DE MEDICAMENTOS LTDA  ACEBROFILINA
# 27     CIMED INDÚSTRIA DE MEDICAMENTOS LTDA  ACEBROFILINA
# 28         LABORATÓRIO TEUTO BRASILEIRO S/A  ACEBROFILINA
# 29     LABORATÓRIO FARMACÊUTICO ELOFAR LTDA       LISOMUC
#
#                                          presentation  \
# 0      10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G
# 1               125 MG/ML SOL INJ CT 1 SER PREENCHIDA
# 2   125 MG/ML SOL INJ CT 4 SER PREENC VD TRANS + D...
# 3      250 MG PO LIOF INJ 1 CT 1 FA + SER DESCARTÁVEL
# 4                 2 MG/ML SOL INJ CT FA VD INC X 5 ML
# 5                 2 MG/ML SOL INJ CT FA VD INC X 5 ML
# 6                      50 MG COM REV CT BL AL AL X 30
# 7                      50 MG COM REV CT BL AL AL X 60
# 8                     100 MG COM REV CT BL AL AL X 30
# 9                     100 MG COM REV CT BL AL AL X 60
# 10                    150 MG COM REV CT BL AL AL X 30
# 11                    150 MG COM REV CT BL AL AL X 60
# 12                    200 MG COM REV CT BL AL AL X 30
# 13                    200 MG COM REV CT BL AL AL X 60
# 14                   100 MG CAP DURA CT BL AL AL X 60
# 15                         50 MG COM CT BL AL/AL X 30
# 16                        100 MG COM CT BL AL/AL X 30
# 17                         50 MG COM CT BL AL AL X 30
# 18                        100 MG COM CT BL AL AL X 30
# 19                50 MG COM CT 3 BL AL PVDC LEIT X 10
# 20               100 MG COM CT 3 BL AL PVDC LEIT X 10
# 21          5 MG/ML XPE CT FR PLAS AMB X 120 ML + COP
# 22         10 MG/ML XPE CT FR PLAS AMB X 120 ML + COP
# 23        10 MG / ML XPE CT FR PET AMB X 120 ML + COP
# 24    5 MG/ML GEL OR CT FR PLAS INC X 120ML + COL MED
# 25         10 MG/ML XPE CT FR PLAS AMB X 120 ML + COP
# 26  5 MG/ML XPE CX 50 FR PLAS AMB X 120 ML + 50 CP...
# 27  10 MG/ML XPE CX 50 FR PLAS AMB X 120 ML + 50 C...
# 28          10 MG/ML XPE CT FR PET AMB X 120 ML + COP
# 29         5 MG / ML XPE CT FR PET AMB X 120 ML + COP
#
#                                                 class        type price_regim  \
# 0   D7B2 - CORTICOESTERÓIDES ASSOCIADOS A ANTIMICO...        Novo    Regulado
# 1           M1C - AGENTES ANTI-REUMÁTICOS ESPECÍFICOS   Biológico    Regulado
# 2           M1C - AGENTES ANTI-REUMÁTICOS ESPECÍFICOS   Biológico    Regulado
# 3           M1C - AGENTES ANTI-REUMÁTICOS ESPECÍFICOS   Biológico    Regulado
# 4   B1C3 - INIBIDORES DA AGREGAÇÃO PLAQUETÁRIA, AN...      -         Regulado
# 5   B1C3 - INIBIDORES DA AGREGAÇÃO PLAQUETÁRIA, AN...        Novo    Regulado
# 6                L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 7                L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 8                L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 9                L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 10               L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 11               L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 12               L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 13               L1H - INIBIDORES DE PROTEINA QUINASE        Novo    Regulado
# 14  L1H9 - OUTROS ANTINEOPLÁSICOS INIBIDORES DA PR...      -         Regulado
# 15  A10L - ANTIDIABÉTICOS INIBIDORES ALFA-GLUCOSIDASE      -         Regulado
# 16  A10L - ANTIDIABÉTICOS INIBIDORES ALFA-GLUCOSIDASE      -         Regulado
# 17  A10L - ANTIDIABÉTICOS INIBIDORES ALFA-GLUCOSIDASE     Similar    Regulado
# 18  A10L - ANTIDIABÉTICOS INIBIDORES ALFA-GLUCOSIDASE     Similar    Regulado
# 19  A10L - ANTIDIABÉTICOS INIBIDORES ALFA-GLUCOSIDASE     Similar    Regulado
# 20  A10L - ANTIDIABÉTICOS INIBIDORES ALFA-GLUCOSIDASE     Similar    Regulado
# 21                                R5C - EXPECTORANTES    Genérico    Regulado
# 22                                R5C - EXPECTORANTES    Genérico    Regulado
# 23                                R5C - EXPECTORANTES     Similar    Regulado
# 24                                R5C - EXPECTORANTES        Novo    Regulado
# 25                                R5C - EXPECTORANTES    Genérico    Regulado
# 26                                R5C - EXPECTORANTES    Genérico    Regulado
# 27                                R5C - EXPECTORANTES    Genérico    Regulado
# 28                                R5C - EXPECTORANTES    Genérico    Regulado
# 29                                R5C - EXPECTORANTES     Similar    Regulado
#
#    fabricprice_no_tax fabricprice_less_than_1%_tax  ... marketprice_17.5%_tax  \
# 0               19.74                        22.11  ...                 36.66
# 1             1228.49                      1228.49  ...               2058.57
# 2             4914.04                      4914.04  ...               8234.39
# 3             1547.45                      1547.45  ...                     0
# 4             2003.06                      2003.06  ...                     0
# 5             2003.06                      2003.06  ...                     0
# 6             2077.84                      2327.18  ...               3859.06
# 7             4155.68                      4654.36  ...               7718.12
# 8             4155.68                      4654.36  ...               7718.12
# 9             8311.34                       9308.7  ...               15436.2
# 10             5967.2                      6683.27  ...               11082.6
# 11            11934.4                      13366.5  ...               22165.2
# 12               7452                      8346.24  ...               13840.2
# 13              14904                      16692.5  ...               27680.4
# 14            38240.6                      42829.4  ...               71022.2
# 15              31.17                        31.17  ...                 52.23
# 16              46.53                        46.53  ...                 77.97
# 17              19.63                        19.63  ...                 32.89
# 18              29.79                        29.79  ...                 49.92
# 19              19.63                        19.63  ...                 32.89
# 20              29.79                        29.79  ...                 49.92
# 21              13.24                        13.24  ...                 22.19
# 22              18.69                        18.69  ...                 31.31
# 23              22.92                        22.92  ...                  38.4
# 24              13.25                        13.25  ...                  22.2
# 25              17.45                        17.45  ...                 29.24
# 26             540.33                       540.33  ...                     0
# 27             648.38                       648.38  ...                     0
# 28               18.5                         18.5  ...                 30.99
# 29              15.83                        15.83  ...                 26.53
#
#    marketprice_17.5%ALC_tax marketprice_18%_tax marketprice_18%ALC_tax  \
# 0                     33.08               36.92                  33.28
# 1                   2058.57             2071.12                2071.12
# 2                   8234.39              8284.6                 8284.6
# 3                         0                   0                      0
# 4                         0                   0                      0
# 5                         0                   0                      0
# 6                    3481.8             3885.29                3503.04
# 7                   6963.62              7770.6                7006.07
# 8                   6963.62              7770.6                7006.07
# 9                   13927.2             15541.1                14012.1
# 10                  9999.17             11157.9                10060.1
# 11                  19998.3             22315.8                20120.3
# 12                  12487.2             13934.3                12563.4
# 13                  24974.4             27868.6                25126.7
# 14                  64079.2             71505.1                64469.9
# 15                    52.23               52.55                  52.55
# 16                    77.97               78.44                  78.44
# 17                    32.89                33.1                   33.1
# 18                    49.92               50.22                  50.22
# 19                    32.89                33.1                   33.1
# 20                    49.92               50.22                  50.22
# 21                    22.19               22.33                  22.33
# 22                    31.31               31.51                  31.51
# 23                     38.4               38.64                  38.64
# 24                     22.2               22.34                  22.34
# 25                    29.24               29.42                  29.42
# 26                        0                   0                      0
# 27                        0                   0                      0
# 28                    30.99               31.19                  31.19
# 29                    26.53               26.68                  26.68
#
#    marketprice_20%_tax restriction icms_no_tax tribute_credit  \
# 0                37.95         Não         Não       Negativa
# 1              2122.89         Não         Não       Positiva
# 2              8491.72         Não         Não       Positiva
# 3                    0         Sim         Não       Positiva
# 4                    0         Sim         Não       Positiva
# 5                    0         Sim         Não       Positiva
# 6              3993.95         Não         Não       Negativa
# 7              7987.92         Não         Não       Negativa
# 8              7987.92         Não         Não       Negativa
# 9              15975.8         Não         Não       Negativa
# 10               11470         Não         Não       Negativa
# 11               22940         Não         Não       Negativa
# 12               14324         Não         Não       Negativa
# 13               28648         Não         Não       Negativa
# 14             73504.9         Não         Não       Negativa
# 15               53.86         Não         Não       Positiva
# 16                80.4         Não         Não       Positiva
# 17               33.93         Não         Não       Positiva
# 18               51.48         Não         Não       Positiva
# 19               33.93         Não         Não       Positiva
# 20               51.48         Não         Não       Positiva
# 21               22.88         Não         Não       Positiva
# 22               32.29         Não         Não       Positiva
# 23               39.61         Não         Não       Positiva
# 24               22.89         Não         Não       Positiva
# 25               30.15         Não         Não       Positiva
# 26                   0         Sim         Não       Positiva
# 27                   0         Sim         Não       Positiva
# 28               31.98         Não         Não       Positiva
# 29               27.36         Não         Não       Positiva
#
#    comercialization_last_year                      label
# 0                         Sim             Tarja Vermelha
# 1                         Não             Tarja Vermelha
# 2                         Sim         Tarja Vermelha (*)
# 3                         Sim             Tarja Vermelha
# 4                         Sim         Tarja Vermelha (*)
# 5                         Não         Tarja Vermelha (*)
# 6                         Sim         Tarja Vermelha (*)
# 7                         Não         Tarja Vermelha (*)
# 8                         Sim         Tarja Vermelha (*)
# 9                         Não         Tarja Vermelha (*)
# 10                        Sim         Tarja Vermelha (*)
# 11                        Sim         Tarja Vermelha (*)
# 12                        Sim         Tarja Vermelha (*)
# 13                        Sim  Venda Livre/Sem Tarja (*)
# 14                        Sim         Tarja Vermelha (*)
# 15                        Sim             Tarja Vermelha
# 16                        Sim             Tarja Vermelha
# 17                        Sim         Tarja Vermelha (*)
# 18                        Sim         Tarja Vermelha (*)
# 19                        Sim             Tarja Vermelha
# 20                        Sim             Tarja Vermelha
# 21                        Sim         Tarja Vermelha (*)
# 22                        Sim             Tarja Vermelha
# 23                        Sim         Tarja Vermelha (*)
# 24                        Sim             Tarja Vermelha
# 25                        Não             Tarja Vermelha
# 26                        Sim         Tarja Vermelha (*)
# 27                        Sim             Tarja Vermelha
# 28                        Sim             Tarja Vermelha
# 29                        Sim             Tarja Vermelha
#
# [30 rows x 32 columns]

# %%
es = Elasticsearch(HOST="http://localhost", PORT="9200")

# %%
if es.ping():
    print('Connection succesfully established')
else:
    print("Couldn't connect to the Elasticsearch server")
# Out:
# Connection succesfully established

# %%
def create_or_modify_index(indexname, settings):
    try:
        if not es.indices.exists(indexname):
            print(f"Index '{indexname}' doesn't exists")
            print(f"Creating new index '{indexname}'")
        
            es.indices.create(index=indexname, body=settings)
            print(f"'{indexname}' was succesfuly created")
        else:
            print(f"'{indexname} already exists")
    except Exception as ex:
        print(str(ex))

# %%
settings = {
            "settings" : {
                "number_of_shards" : 10,
                "number_of_replicas" : 1
            },
            "mappings" : {
                "properties" : {
                    "substance" : {
                        "type" : "text"
                    },
                    "cnpj" : {
                        "type" : "text"
                    },
                    "lab" : {
                        "type" : "text"
                    },
                    "product" : {
                        "type" : "text"
                    },
                    "presentation" : {
                        "type" : "text"
                    },
                    "class" : {
                        "type" : "text"
                    },
                    "type" : {
                        "type" : "text"
                    },
                    "price_regim" : {
                        "type" : "text"
                    },
                    "fabricprice_no_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_less_than_1%_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_12%_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_17%_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_17%ALC_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_17.5%_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_17.5%ALC_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_18%_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_18%ALC_tax" : {
                        "type" : "float"
                    },
                    "fabricprice_20%_tax" : {
                        "type" : "float"
                    },
                    "marketprice_less_than_1%_tax" : {
                        "type" : "float"
                    },
                    "marketprice_12%_tax" : {
                        "type" : "float"
                    },
                    "marketprice_17%_tax" : {
                        "type" : "float"
                    },
                    "marketprice_17%ALC_tax" : {
                        "type" : "float"
                    },
                    "marketprice_17.5%_tax" : {
                        "type" : "float"
                    },
                    "marketprice_17.5%ALC_tax" : {
                        "type" : "float"
                    },
                    "marketprice_18%_tax" : {
                        "type" : "float"
                    },
                    "marketprice_18%ALC_tax" : {
                        "type" : "float"
                    },
                    "marketprice_20%_tax" : {
                        "type" : "float"
                    },
                    "restriction" : {
                        "type" : "text"
                    },
                    "icms_no_tax" : {
                        "type" : "text"
                    },
                    "tribute_credit" : {
                        "type" : "text"
                    },
                    "comercialization_last_year" : {
                        "type" : "text"
                    },
                    "label" : {
                        "type" : "text"
                    }
                }
            }
        }

indexname = "drugs"

create_or_modify_index(indexname, settings)
# Out:
# Index 'drugs' doesn't exists
# Creating new index 'drugs'
# 'drugs' was succesfuly created

# %%
def create_data_container(indexname):
    print("Initiating indexation")
    for row in df.axes[0]:
        doc = {}
        column_count = 0
        
        for col in df.columns:
            doc[col] = df.iloc[row, column_count]
            column_count += 1
            
        doc = json.dumps(doc)
        try:
            es.index(index=indexname, id=1, body=doc)
            print(f'{row/totalrow*100:.1f}% completed', end='\r')
        except Exception:
            print(f'Problematic document in line: {row}')
            print(doc)
            break
            
    print("Concluded")

# %%
create_data_container("drugs")
# Out:
# Initiating indexation
# Concluded
